# %%
import pandas as pd
import numpy as np
QUOTEBANK_2019_NYT = '../../../../quotes-2019-nytimes.json'

# %%
def format_attr(dataframe):
    '''
    Create a new dataframe with all attributes
    formatted according to the gunshot datasets'
    :param dataframe: pandas.DataFrame
    :return: new dataframe
    '''
    formatted_df = pd.DataFrame()
    formatted_df['quoteID'] = df['quoteID'].astype(str)
    formatted_df['quotation'] = df['quotation'].astype(str)
    formatted_df['speaker'] = df['speaker'].astype(str)
    formatted_df['qids'] = df['qids']
    formatted_df['date'] = df['date'].astype(str)
    formatted_df['numOccurrences'] = df['numOccurrences'].astype(int)
    formatted_df['probas'] = df['probas']
    formatted_df['urls'] = df['urls']
    formatted_df['phase'] = df['phase'].astype(str)
    return formatted_df

# %%
df = pd.read_json(QUOTEBANK_2019_NYT, lines=True)
df = df.dropna()
df = format_attr(df)
df
# Out:
#                   quoteID                                          quotation  \
# 0       2019-04-17-024782                It is not a low-income immigration,
# 1       2019-04-02-001128  a champion figure skater switching to roller s...
# 2       2019-05-09-055187  It makes it much more difficult for him to mak...
# 3       2019-10-31-056366                       It puts me in a predicament,
# 4       2019-01-04-001792                                  A Pile of Leaves.
# ...                   ...                                                ...
# 207522  2019-07-11-031126  I put in one of those wire shelves that you bu...
# 207523  2019-06-25-032409  I used to go there religiously and buy anythin...
# 207524  2019-05-02-043481  I was the welterweight boxing champ at St. Mik...
# 207525  2019-01-19-026354  In terms of changing Taiwan's situation for th...
# 207526  2019-12-05-049752  It has the urgency of a news bulletin and the ...
#
#                       speaker  \
# 0                James Fisher
# 1                 John Updike
# 2                        None
# 3              Xavier Becerra
# 4                        None
# ...                       ...
# 207522                   None
# 207523         Carlos Santana
# 207524  Leonard Patrick Kelly
# 207525                   None
# 207526            A. O. Scott
#
#                                                      qids  \
# 0       [Q16213953, Q20707104, Q43143598, Q58886302, Q...
# 1                                               [Q105756]
# 2                                                      []
# 3                                              [Q1855840]
# 4                                                      []
# ...                                                   ...
# 207522                                                 []
# 207523                      [Q2367902, Q5042623, Q819016]
# 207524                                         [Q7143620]
# 207525                                                 []
# 207526                                           [Q38351]
#
#                        date  numOccurrences  \
# 0       2019-04-17 13:31:18               1
# 1       2019-04-02 14:58:33               2
# 2       2019-05-09 18:11:29               1
# 3       2019-10-31 16:45:15               3
# 4       2019-01-04 10:00:07               1
# ...                     ...             ...
# 207522  2019-07-11 04:00:15               1
# 207523  2019-06-25 19:52:47               2
# 207524  2019-05-02 21:41:51               3
# 207525  2019-01-19 09:31:37               1
# 207526  2019-12-05 22:00:05               1
#
#                                                    probas  \
# 0                [[James Fisher, 0.7475], [None, 0.2525]]
# 1                 [[John Updike, 0.5856], [None, 0.4144]]
# 2       [[None, 0.6493], [President Bill Clinton, 0.27...
# 3       [[Xavier Becerra, 0.9065], [None, 0.0909], [St...
# 4               [[None, 0.8737], [Jason Fulford, 0.1263]]
# ...                                                   ...
# 207522    [[None, 0.8794], [Marissa Paternoster, 0.1206]]
# 207523  [[Carlos Santana, 0.9484], [None, 0.04], [Rick...
# 207524  [[Leonard Patrick Kelly, 0.5743], [None, 0.388...
# 207525  [[None, 0.7822], [Tsai Ing-wen, 0.1841], [Xi J...
# 207526  [[A. O. Scott, 0.8761], [None, 0.1064], [ALBA ...
#
#                                                      urls phase
# 0       [https://www.nytimes.com/2019/04/17/realestate...     E
# 1       [https://www.nytimes.com/2019/04/02/opinion/vl...     E
# 2       [http://mobile.nytimes.com/2019/05/09/world/as...     E
# 3       [http://www.nytimes.com/2019/10/31/technology/...     E
# 4       [https://www.nytimes.com/2019/01/04/books/revi...     E
# ...                                                   ...   ...
# 207522  [https://www.nytimes.com/2019/07/11/style/band...     E
# 207523  [https://www.nytimes.com/2019/06/25/arts/music...     E
# 207524  [http://nytimes.com/2019/05/02/obituaries/red-...     E
# 207525  [https://www.nytimes.com/2019/01/19/world/asia...     E
# 207526  [https://www.nytimes.com/2019/12/05/movies/nyc...     E
#
# [207527 rows x 9 columns]

# %%
df[(df['speaker'] == 'Mark Cuban')]
# Out:
#                   quoteID                                          quotation  \
# 31494   2019-04-01-057777          I've got nothing to say -- n-o-t-h-i-n-g,
# 84253   2019-11-13-005645  And add that to a new system, new teammates, n...
# 90011   2019-11-12-071869  selling shiny objects to divert attention from...
# 135252  2019-11-13-109058         to try to re-earn their loyalty every day.
# 149358  2019-04-02-127581  When I said federal authorities said for us no...
# 166607  2019-11-13-026979  He is so much further on than I expected after...
# 190595  2019-11-13-034325                      I expected him to be rustier,
# 199734  2019-11-22-102962  to make sure someone didn't do something crazy...
#
#            speaker       qids                 date  numOccurrences  \
# 31494   Mark Cuban  [Q318503]  2019-04-01 23:35:53               2
# 84253   Mark Cuban  [Q318503]  2019-11-13 01:32:30               2
# 90011   Mark Cuban  [Q318503]  2019-11-12 11:00:13               4
# 135252  Mark Cuban  [Q318503]  2019-11-13 16:26:17               1
# 149358  Mark Cuban  [Q318503]  2019-04-02 19:19:28               1
# 166607  Mark Cuban  [Q318503]  2019-11-13 01:32:30               2
# 190595  Mark Cuban  [Q318503]  2019-11-13 01:32:30               2
# 199734  Mark Cuban  [Q318503]  2019-11-22 00:00:00               9
#
#                                                    probas  \
# 31494   [[Mark Cuban, 0.6665], [None, 0.3313], [Krista...
# 84253   [[Mark Cuban, 0.7152], [None, 0.2696], [Krista...
# 90011   [[Mark Cuban, 0.4959], [Elizabeth Warren, 0.23...
# 135252  [[Mark Cuban, 0.7951], [None, 0.19], [Dirk Now...
# 149358  [[Mark Cuban, 0.5903], [None, 0.3648], [Mike B...
# 166607  [[Mark Cuban, 0.7485], [None, 0.227], [Kristap...
# 190595  [[Mark Cuban, 0.6218], [None, 0.3562], [Krista...
# 199734  [[Mark Cuban, 0.5916], [None, 0.323], [Talmage...
#
#                                                      urls phase
# 31494   [https://hoopshype.com/rumor/1249394/, http://...     E
# 84253   [https://basketball.realgm.com/wiretap/256134/...     E
# 90011   [http://www.nytimes.com/2019/11/12/opinion/eli...     E
# 135252  [http://www.nytimes.com/2019/11/13/sports/bask...     E
# 149358  [http://www.nytimes.com/2019/04/02/sports/porz...     E
# 166607  [https://basketball.realgm.com/wiretap/256134/...     E
# 190595  [https://basketball.realgm.com/wiretap/256134/...     E
# 199734  [http://uk.businessinsider.com/mark-cuban-demo...     E
